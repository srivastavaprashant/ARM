# %% [markdown]
# Import Libraries

# %%
import os

# %%
home_dir = '../'
os.chdir(home_dir)
from ext import download_pubmed_articles, search_gene_id, download_gene_names
from norm import normalize_genes
from relation_finder import find_sentences

"""
Required: A valid entrez registered email and entrez api-key.
More information: Entrez Programming Utilities (E-utilities)
"""  
from config import entrez_api_key, entrez_email

# %%
import pandas as pd
import numpy as np
import re

# %%
from Bio import Entrez
import xmltodict

# %% [markdown]
# Preprocessing <b>AIR</b>. <br>
# <a href="https://air.bio.informatik.uni-rostock.de/">Atlas of Inflammation Resolution</a>

# %%
air = pd.read_csv('Data/air_mim.csv')

# %%
air.head(3)
# Out:
#         Source SourceType                                          SourceIDs  \
# 0  ITGAL:ITGB2    COMPLEX                                                NaN
# 1  ITGB4:ITGB1    COMPLEX                                                NaN
# 2       CXCL12    PROTEIN  HGNC:10672, ensembl:ENSG00000107562, uniprot:P...
#
#   InteractionTypeShort InteractionType Modification Modifier ModifierType  \
# 0             positive             NaN          NaN      NaN          NaN
# 1             positive             NaN          NaN      NaN          NaN
# 2             positive             NaN          NaN      NaN          NaN
#
#    ModifierIDs Target TargetType  \
# 0          NaN  ICAM1   RECEPTOR
# 1          NaN  VCAM1   RECEPTOR
# 2          NaN  CXCR4   RECEPTOR
#
#                                            TargetIDs  \
# 0  ensembl:ENSG00000090339, ncbigene:3383, HGNC:5...
# 1  HGNC:12663, ensembl:ENSG00000162692, uniprot:P...
# 2  ensembl:ENSG00000121966, ncbigene:7852, HGNC:2...
#
#                     Reference
# 0                    15300248
# 1            10626664;7504895
# 2  22220212;16267013;27180275

# %%
print('No of entries in AIR:', air.shape[0])
# Out:
# No of entries in AIR: 19230

# %%
# Drop datapoints without reference. 
air = air[~air.Reference.isna()]
air.Reference = air.Reference.apply(lambda x: [i for i in x.split(';') if i.isdigit()])

# %%
# Create a list of all Pubmed IDs
pubmed_list = [j for i in air.Reference.to_list() for j in i]
# Download abstracts from pubmed IDs.
res = download_pubmed_articles(entrez_api_key, entrez_email, pubmed_list)
# Out:
# No of unique pubmed ids: 15625
# Downloading from pubmed db...
# Decoding downloaded data...
# Parsing to a dict...
# 9997 pubmed matches found out of 15625 pubmed articles.
# Extracting abstracts and titles...
# Done!

# %%
# Create DataFrame for downloaded pubmed articles.
pubmed_articles = pd.DataFrame(res).dropna()
pubmed_articles.index = pubmed_articles.pubmed
pubmed_articles.index.name = 'pmid'
pubmed_articles.head(5)
# Out:
#             pubmed                                              title  \
# pmid
# 21761340  21761340  Prostate cancer stem cells: do they have a bas...
# 26663434  26663434  Systemic genome screening identifies the outco...
# 23970470  23970470  Inhibitory effect of microRNA-34a on retinal p...
# 12057865  12057865  A myeloperoxidase polymorphism associated with...
# 20533062  20533062  The CAG repeat in SCA12 functions as a cis ele...
#
#                                                    abstract
# pmid
# 21761340  The prostate is a luminal secretory tissue who...
# 26663434  Systemic analyses using large-scale genomic pr...
# 23970470  Retinal pigment epithelial (RPE) cells play im...
# 12057865  Myeloperoxidase (MPO) is a metabolic/oxidative...
# 20533062  PPP2R2B, a protein widely expressed in neurons...

# %%
# Create datapoint for each Pubmed id reference 
air = air.explode(column = 'Reference')
air = air[~air.Reference.isna()]
air.index = air.Reference
air.index.name = 'pmid'
air.head(5)
# Out:
#                Source SourceType  \
# pmid
# 15300248  ITGAL:ITGB2    COMPLEX
# 10626664  ITGB4:ITGB1    COMPLEX
# 7504895   ITGB4:ITGB1    COMPLEX
# 22220212       CXCL12    PROTEIN
# 16267013       CXCL12    PROTEIN
#
#                                                   SourceIDs  \
# pmid
# 15300248                                                NaN
# 10626664                                                NaN
# 7504895                                                 NaN
# 22220212  HGNC:10672, ensembl:ENSG00000107562, uniprot:P...
# 16267013  HGNC:10672, ensembl:ENSG00000107562, uniprot:P...
#
#          InteractionTypeShort InteractionType Modification Modifier  \
# pmid
# 15300248             positive             NaN          NaN      NaN
# 10626664             positive             NaN          NaN      NaN
# 7504895              positive             NaN          NaN      NaN
# 22220212             positive             NaN          NaN      NaN
# 16267013             positive             NaN          NaN      NaN
#
#          ModifierType  ModifierIDs Target TargetType  \
# pmid
# 15300248          NaN          NaN  ICAM1   RECEPTOR
# 10626664          NaN          NaN  VCAM1   RECEPTOR
# 7504895           NaN          NaN  VCAM1   RECEPTOR
# 22220212          NaN          NaN  CXCR4   RECEPTOR
# 16267013          NaN          NaN  CXCR4   RECEPTOR
#
#                                                   TargetIDs Reference
# pmid
# 15300248  ensembl:ENSG00000090339, ncbigene:3383, HGNC:5...  15300248
# 10626664  HGNC:12663, ensembl:ENSG00000162692, uniprot:P...  10626664
# 7504895   HGNC:12663, ensembl:ENSG00000162692, uniprot:P...   7504895
# 22220212  ensembl:ENSG00000121966, ncbigene:7852, HGNC:2...  22220212
# 16267013  ensembl:ENSG00000121966, ncbigene:7852, HGNC:2...  16267013

# %%
# Merge AIR with pumed dataframe
df = air.join(pubmed_articles).dropna(subset = ['abstract'])
df = df[['Source', 'Target', 'InteractionTypeShort', 'abstract']]
df.columns = ['source', 'target', 'interaction', 'abstract']
df.head(5)
# Out:
#           source  target interaction  \
# pmid
# 10022118  CDKN1A    CDK2    negative
# 10022118   CASP3  CDKN1A    negative
# 10022513     ERG   HMOX1    positive
# 10022513    ETS1   HMOX1    positive
# 10022513    FLI1   HMOX1    positive
#
#                                                    abstract
# pmid
# 10022118  The cyclin-dependent kinase inhibitor p21waf1/...
# 10022118  The cyclin-dependent kinase inhibitor p21waf1/...
# 10022513  Overexpression of human heme oxygenase-1 has b...
# 10022513  Overexpression of human heme oxygenase-1 has b...
# 10022513  Overexpression of human heme oxygenase-1 has b...

# %%
# Get all the gene names, search and download genes.
gene_name_list = df.source.to_list() + df.target.to_list()
gene_search_res = search_gene_id(entrez_api_key, entrez_email, gene_name_list)
gene_ids = [i['id'] for i in gene_search_res]
gene_dict = download_gene_names(entrez_api_key, entrez_email, gene_ids)
# Out:
# 4678 unique gene names...
# Searching...
# No of unique gene ids: 4415s...
# Downloading from gene db...
# Decoding downloaded data...
# Parsing to a dict
# 4365 found.

# %%
# Normalize genes
df['abstract'] = normalize_genes(gene_dict, df.source.to_list(), df.target.to_list(), df.abstract.to_list())
# Out:
# 16835 abstracts to be normalized...
# 16835 abstracts normalized...
# Done!

# %%
# Find sentences with gene mentions
rel_df = find_sentences(df)
rel_df.head(5)
# Out:
# 16835 abstracts...
# 164451 sentences found...
# 30214 sentences have a relation information.
#           source  target interaction  \
# pmid
# 10022118  CDKN1A    CDK2    negative
# 10022118  CDKN1A    CDK2    negative
# 10022118  CDKN1A    CDK2    negative
# 10022118  CDKN1A    CDK2    negative
# 10022118   CASP3  CDKN1A    negative
#
#                                                    abstract  \
# pmid
# 10022118  The cyclin-dependent kinase inhibitor cdkn1acd...
# 10022118  The cyclin-dependent kinase inhibitor cdkn1acd...
# 10022118  The cyclin-dependent kinase inhibitor cdkn1acd...
# 10022118  The cyclin-dependent kinase inhibitor cdkn1acd...
# 10022118  The cyclin-dependent kinase inhibitor cdkn1acd...
#
#                                                    sentence  n_lines  match
# pmid
# 10022118  The cyclindependent kinase inhibitor cdkn1acdk...      747      0
# 10022118   We report herein that cdkn1a was cleaved by c...      747      0
# 10022118   The cleaved cdkn1a fragment could no more arr...      747      0
# 10022118   Thus caspase3mediated cleavage and inactivati...      747      0
# 10022118  The cyclindependent kinase inhibitor cdkn1acdk...      752      0

# %%
rel_df = rel_df[['source', 'target', 'interaction', 'sentence', 'match']]

# %%
rel_df.to_csv('air_norm_rel.csv')
